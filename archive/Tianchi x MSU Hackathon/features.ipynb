# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import pandas as pd
from tqdm import tqdm_notebook as tqdm


test = pd.read_csv('round1_ijcai_18_test_b_20180418.txt', sep=' ')

train = pd.read_csv('round1_ijcai_18_train_20180301 (1).zip', sep=' ')

sample_sub = pd.read_csv('round1_ijcai_18_result_demo_20180301.txt', sep=' ')

train.nunique()

import time
def preprocess(train):
    def timestamp2datetime(ts):
        dt = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(ts))
        return dt
    train['Timestamp'] = train.context_timestamp.apply(timestamp2datetime)
    train = train.drop(['context_timestamp'], axis=1)
    def time_preprocess(X):
        X['Timestamp'] = pd.to_datetime(X['Timestamp'])
#         X['year'] = X['Timestamp'].dt.year
#         X['month'] = X['Timestamp'].dt.month 
        X['day'] = X['Timestamp'].dt.day
        X['week_day'] = X['Timestamp'].dt.weekday
        X['hour'] = X['Timestamp'].dt.hour
        X['minute'] = X['Timestamp'].dt.minute
        X['minute'] = X['minute'] // 15 * 15
        X = X.drop('Timestamp', axis=1)    
        return X
    train = time_preprocess(train)

    train['item_category_list'] = pd.to_numeric(train.item_category_list.str.split(';', expand=True)[1])

    df = train.item_property_list.str.split(';', expand=True)

    df = df.iloc[:, :21].fillna(-1).apply(pd.to_numeric)
    train = pd.concat([train, df], axis=1).reset_index(drop=True).drop('item_property_list', axis=1)

    train['predict_category_property'] = train.predict_category_property.str.split(';',
                                                                                   expand=True).isnull().sum(axis=1)
    train.columns = list(map(str, train.columns.tolist()))

    return train
train = preprocess(train)
test = preprocess(test)

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(train)
rejected_variables = profile.get_rejected_variables(threshold=0.9)
rejected_variables

# %%
# X_train = pd.concat([test, train.drop('is_trade', axis=1)], ignore_index=True).reset_index(drop=True)
X_train = train.copy()

# %%
import gc

aggs = ['count', 'var', 'mean', 'nunique', 'cumcount']
cols2select = ["item_sales_level", 'item_price_level', 'item_price_level', 'item_pv_level', 'hour', 'minute',
               'shop_score_service']
arr2group = [['user_id'], ['user_id', 'context_id']]

GROUPBY_AGGREGATIONS = [
    
    # V1 - GroupBy Features #
    #########################    
    # Variance in day, for ip-app-channel
#     {'groupby': ['user_id'], 'select': 'item_price_level', 'agg': 'count'}
]
for arr in arr2group:
    for col in cols2select:
        for agg in aggs:
            GROUPBY_AGGREGATIONS.append({'groupby': arr, 'select': col, 'agg': agg})


for spec in GROUPBY_AGGREGATIONS:
    
    # Name of the aggregation we're applying
    agg_name = spec['agg_name'] if 'agg_name' in spec else spec['agg']
    
    # Name of new feature
    new_feature = '{}_{}_{}'.format('_'.join(spec['groupby']), agg_name, spec['select'])
    
    # Info
    print("Grouping by {}, and aggregating {} with {}".format(
        spec['groupby'], spec['select'], agg_name
    ))
    
    # Unique list of features to select
    all_features = list(set(spec['groupby'] + [spec['select']]))
    
    # Perform the groupby
    gp = X_train[all_features]. \
        groupby(spec['groupby'])[spec['select']]. \
        agg(spec['agg']). \
        reset_index(). \
        rename(index=str, columns={spec['select']: new_feature})
        
    # Merge back to X_total
    if 'cumcount' == spec['agg']:
        X_train[new_feature] = gp[0].values
    else:
        X_train = X_train.merge(gp, on=spec['groupby'], how='left')
        
     # Clear memory
    del gp
    gc.collect()
# Out:
# Grouping by ['user_id'], and aggregating item_sales_level with count
# Grouping by ['user_id'], and aggregating item_sales_level with var
# Grouping by ['user_id'], and aggregating item_sales_level with mean
# Grouping by ['user_id'], and aggregating item_sales_level with nunique
# Grouping by ['user_id'], and aggregating item_sales_level with cumcount
# Grouping by ['user_id'], and aggregating item_price_level with count
# Grouping by ['user_id'], and aggregating item_price_level with var
# Grouping by ['user_id'], and aggregating item_price_level with mean
# Grouping by ['user_id'], and aggregating item_price_level with nunique
# Grouping by ['user_id'], and aggregating item_price_level with cumcount
# Grouping by ['user_id'], and aggregating item_price_level with count
# Grouping by ['user_id'], and aggregating item_price_level with var
# Grouping by ['user_id'], and aggregating item_price_level with mean
# Grouping by ['user_id'], and aggregating item_price_level with nunique
# Grouping by ['user_id'], and aggregating item_price_level with cumcount
# Grouping by ['user_id'], and aggregating item_pv_level with count
# Grouping by ['user_id'], and aggregating item_pv_level with var
# Grouping by ['user_id'], and aggregating item_pv_level with mean
# Grouping by ['user_id'], and aggregating item_pv_level with nunique
# Grouping by ['user_id'], and aggregating item_pv_level with cumcount
# Grouping by ['user_id'], and aggregating hour with count
# Grouping by ['user_id'], and aggregating hour with var
# Grouping by ['user_id'], and aggregating hour with mean
# Grouping by ['user_id'], and aggregating hour with nunique
# Grouping by ['user_id'], and aggregating hour with cumcount
# Grouping by ['user_id'], and aggregating minute with count
# Grouping by ['user_id'], and aggregating minute with var
# Grouping by ['user_id'], and aggregating minute with mean
# Grouping by ['user_id'], and aggregating minute with nunique
# Grouping by ['user_id'], and aggregating minute with cumcount
# Grouping by ['user_id'], and aggregating shop_score_service with count
# Grouping by ['user_id'], and aggregating shop_score_service with var
# Grouping by ['user_id'], and aggregating shop_score_service with mean
# Grouping by ['user_id'], and aggregating shop_score_service with nunique
# Grouping by ['user_id'], and aggregating shop_score_service with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating item_sales_level with count
# Grouping by ['user_id', 'context_id'], and aggregating item_sales_level with var
# Grouping by ['user_id', 'context_id'], and aggregating item_sales_level with mean
# Grouping by ['user_id', 'context_id'], and aggregating item_sales_level with nunique
# Grouping by ['user_id', 'context_id'], and aggregating item_sales_level with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with count
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with var
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with mean
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with nunique
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with count
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with var
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with mean
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with nunique
# Grouping by ['user_id', 'context_id'], and aggregating item_price_level with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating item_pv_level with count
# Grouping by ['user_id', 'context_id'], and aggregating item_pv_level with var
# Grouping by ['user_id', 'context_id'], and aggregating item_pv_level with mean
# Grouping by ['user_id', 'context_id'], and aggregating item_pv_level with nunique
# Grouping by ['user_id', 'context_id'], and aggregating item_pv_level with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating hour with count
# Grouping by ['user_id', 'context_id'], and aggregating hour with var
# Grouping by ['user_id', 'context_id'], and aggregating hour with mean
# Grouping by ['user_id', 'context_id'], and aggregating hour with nunique
# Grouping by ['user_id', 'context_id'], and aggregating hour with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating minute with count
# Grouping by ['user_id', 'context_id'], and aggregating minute with var
# Grouping by ['user_id', 'context_id'], and aggregating minute with mean
# Grouping by ['user_id', 'context_id'], and aggregating minute with nunique
# Grouping by ['user_id', 'context_id'], and aggregating minute with cumcount
# Grouping by ['user_id', 'context_id'], and aggregating shop_score_service with count
# Grouping by ['user_id', 'context_id'], and aggregating shop_score_service with var
# Grouping by ['user_id', 'context_id'], and aggregating shop_score_service with mean
# Grouping by ['user_id', 'context_id'], and aggregating shop_score_service with nunique
# Grouping by ['user_id', 'context_id'], and aggregating shop_score_service with cumcount

# %% [raw]
# X_train = X_train.iloc[:train.shape[0], :]
# # X_train =
# X_train = pd.concat([X_train, train.is_trade], axis=1)

# %%
from sklearn.model_selection import train_test_split
to_drop = ['index','instance_id']
# to_drop = []
x_train, x_test, y_train, y_test = train_test_split(
    X_train.drop(['is_trade'] + to_drop + rejected_variables, axis=1).values, X_train['is_trade'].values,
    test_size=0.2)

from sklearn.metrics import log_loss
import lightgbm as lgb
import telepyth # push notif in telegram
# %telepyth -t 1260389131217015787
# %load_ext wurlitzer
verbose = 1
plot = 1
params = {
#     "max_bin": 1024,
#     "learning_rate": 0.01,
    "boosting_type": "dart",
    "objective": "binary",
    'num_iterations':1200,
    "metric": "binary",
    "num_leaves": 2**12,
    "verbose": 1,
    "min_data_in_leaf": 40,
#     "boost_from_average": True
    'early_stopping_round': 150,
    'bagging_fraction':0.7

}

d_train = lgb.Dataset(x_train, y_train)
d_valid = lgb.Dataset(x_test, label=y_test)
model = lgb.train(params, d_train, valid_sets=d_valid)

df_fi = pd.DataFrame(X_train.drop(['is_trade'] + to_drop + rejected_variables, axis=1).columns, columns=['feature'])
df_fi['importance'] = list(model.feature_importance('gain'))
df_fi.sort_values('importance', ascending=False, inplace=True)
if plot:
    plt.figure()
    df_fi.head(10).plot(kind='barh', x='feature', y='importance')
#     plt.title('Roc_auc is {}'.format(roc_auc_score(y_test, y_pred)))
    plt.xlabel('relative importance')
    plt.show()
# Out:
# Use token 1260389131217015787.
# /home/magas/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/lightgbm/engine.py:99: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/magas/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/lightgbm/engine.py:104: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# The wurlitzer extension is already loaded. To reload it, use:
#   %reload_ext wurlitzer
# [LightGBM] [Info] Number of positive: 7211, number of negative: 375299
# [LightGBM] [Info] Total Bins 11531
# [LightGBM] [Info] Number of data: 382510, number of used features: 100
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.605155
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's binary_logloss: 0.533177
# [3]	valid_0's binary_logloss: 0.473255
# [4]	valid_0's binary_logloss: 0.422766
# [5]	valid_0's binary_logloss: 0.379819
# [6]	valid_0's binary_logloss: 0.342975
# [7]	valid_0's binary_logloss: 0.31118
# [8]	valid_0's binary_logloss: 0.324912
# [9]	valid_0's binary_logloss: 0.295552
# [10]	valid_0's binary_logloss: 0.270069
# [11]	valid_0's binary_logloss: 0.247831
# [12]	valid_0's binary_logloss: 0.256222
# [13]	valid_0's binary_logloss: 0.235701
# [14]	valid_0's binary_logloss: 0.217744
# [15]	valid_0's binary_logloss: 0.202029
# [16]	valid_0's binary_logloss: 0.188206
# [17]	valid_0's binary_logloss: 0.176057
# [18]	valid_0's binary_logloss: 0.165365
# [19]	valid_0's binary_logloss: 0.155937
# [20]	valid_0's binary_logloss: 0.147671
# [21]	valid_0's binary_logloss: 0.150248
# [22]	valid_0's binary_logloss: 0.142616
# [23]	valid_0's binary_logloss: 0.135906
# [24]	valid_0's binary_logloss: 0.130017
# [25]	valid_0's binary_logloss: 0.12482
# [26]	valid_0's binary_logloss: 0.12023
# [27]	valid_0's binary_logloss: 0.1162
# [28]	valid_0's binary_logloss: 0.117821
# [29]	valid_0's binary_logloss: 0.114084
# [30]	valid_0's binary_logloss: 0.110806
# [31]	valid_0's binary_logloss: 0.111254
# [32]	valid_0's binary_logloss: 0.108298
# [33]	valid_0's binary_logloss: 0.105755
# [34]	valid_0's binary_logloss: 0.103494
# [35]	valid_0's binary_logloss: 0.104751
# [36]	valid_0's binary_logloss: 0.106983
# [37]	valid_0's binary_logloss: 0.104587
# [38]	valid_0's binary_logloss: 0.102495
# [39]	valid_0's binary_logloss: 0.100706
# [40]	valid_0's binary_logloss: 0.100382
# [41]	valid_0's binary_logloss: 0.101572
# [42]	valid_0's binary_logloss: 0.0999148
# [43]	valid_0's binary_logloss: 0.100922
# [44]	valid_0's binary_logloss: 0.0993199
# [45]	valid_0's binary_logloss: 0.0979411
# [46]	valid_0's binary_logloss: 0.09962
# [47]	valid_0's binary_logloss: 0.0981697
# [48]	valid_0's binary_logloss: 0.0981518
# [49]	valid_0's binary_logloss: 0.0991481
# [50]	valid_0's binary_logloss: 0.100301
# [51]	valid_0's binary_logloss: 0.0987846
# [52]	valid_0's binary_logloss: 0.0974577
# [53]	valid_0's binary_logloss: 0.0982485
# [54]	valid_0's binary_logloss: 0.0970236
# [55]	valid_0's binary_logloss: 0.0959231
# [56]	valid_0's binary_logloss: 0.0968036
# [57]	valid_0's binary_logloss: 0.0957842
# [58]	valid_0's binary_logloss: 0.0967853
# [59]	valid_0's binary_logloss: 0.097815
# [60]	valid_0's binary_logloss: 0.0965461
# [61]	valid_0's binary_logloss: 0.0973324
# [62]	valid_0's binary_logloss: 0.0961689
# [63]	valid_0's binary_logloss: 0.095209
# [64]	valid_0's binary_logloss: 0.09584
# [65]	valid_0's binary_logloss: 0.0963811
# [66]	valid_0's binary_logloss: 0.0954028
# [67]	valid_0's binary_logloss: 0.0945862
# [68]	valid_0's binary_logloss: 0.0938911
# [69]	valid_0's binary_logloss: 0.0942849
# [70]	valid_0's binary_logloss: 0.0945281
# [71]	valid_0's binary_logloss: 0.0950002
# [72]	valid_0's binary_logloss: 0.0942144
# [73]	valid_0's binary_logloss: 0.0936477
# [74]	valid_0's binary_logloss: 0.0939023
# [75]	valid_0's binary_logloss: 0.0933749
# [76]	valid_0's binary_logloss: 0.0934005
# [77]	valid_0's binary_logloss: 0.0936378
# [78]	valid_0's binary_logloss: 0.0939872
# [79]	valid_0's binary_logloss: 0.0934539
# [80]	valid_0's binary_logloss: 0.0929997
# [81]	valid_0's binary_logloss: 0.0932271
# [82]	valid_0's binary_logloss: 0.0928726
# [83]	valid_0's binary_logloss: 0.0931078
# [84]	valid_0's binary_logloss: 0.0933273
# [85]	valid_0's binary_logloss: 0.0936161
# [86]	valid_0's binary_logloss: 0.0931282
# [87]	valid_0's binary_logloss: 0.0927789
# [88]	valid_0's binary_logloss: 0.0930015
# [89]	valid_0's binary_logloss: 0.0932131
# [90]	valid_0's binary_logloss: 0.0934676
# [91]	valid_0's binary_logloss: 0.0937761
# [92]	valid_0's binary_logloss: 0.0932783
# [93]	valid_0's binary_logloss: 0.0928919
# [94]	valid_0's binary_logloss: 0.0930568
# [95]	valid_0's binary_logloss: 0.093254
# [96]	valid_0's binary_logloss: 0.093464
# [97]	valid_0's binary_logloss: 0.0929991
# [98]	valid_0's binary_logloss: 0.0932127
# [99]	valid_0's binary_logloss: 0.0928641
# [100]	valid_0's binary_logloss: 0.0925878
# [101]	valid_0's binary_logloss: 0.0927934
# [102]	valid_0's binary_logloss: 0.0929321
# [103]	valid_0's binary_logloss: 0.0931313
# [104]	valid_0's binary_logloss: 0.0927644
# [105]	valid_0's binary_logloss: 0.0929907
# [106]	valid_0's binary_logloss: 0.0932169
# [107]	valid_0's binary_logloss: 0.0934749
# [108]	valid_0's binary_logloss: 0.0930036
# [109]	valid_0's binary_logloss: 0.0931785
# [110]	valid_0's binary_logloss: 0.0934107
# [111]	valid_0's binary_logloss: 0.0929311
# [112]	valid_0's binary_logloss: 0.0925636
# [113]	valid_0's binary_logloss: 0.0923276
# [114]	valid_0's binary_logloss: 0.0922035
# [115]	valid_0's binary_logloss: 0.0921912
# [116]	valid_0's binary_logloss: 0.0922607
# [117]	valid_0's binary_logloss: 0.0922292
# [118]	valid_0's binary_logloss: 0.0923044
# [119]	valid_0's binary_logloss: 0.0922435
# [120]	valid_0's binary_logloss: 0.0921979
# [121]	valid_0's binary_logloss: 0.0921688
# [122]	valid_0's binary_logloss: 0.0921757
# [123]	valid_0's binary_logloss: 0.0922039
# [124]	valid_0's binary_logloss: 0.0923096
# [125]	valid_0's binary_logloss: 0.0922694
# [126]	valid_0's binary_logloss: 0.0922091
# [127]	valid_0's binary_logloss: 0.0923001
# [128]	valid_0's binary_logloss: 0.0922479
# [129]	valid_0's binary_logloss: 0.0923515
# [130]	valid_0's binary_logloss: 0.0925327
# [131]	valid_0's binary_logloss: 0.0924246
# [132]	valid_0's binary_logloss: 0.0926535
# [133]	valid_0's binary_logloss: 0.0929614
# [134]	valid_0's binary_logloss: 0.0927826
# [135]	valid_0's binary_logloss: 0.0931315
# [136]	valid_0's binary_logloss: 0.0929201
# [137]	valid_0's binary_logloss: 0.0927716
# [138]	valid_0's binary_logloss: 0.0930564
# [139]	valid_0's binary_logloss: 0.0933882
# [140]	valid_0's binary_logloss: 0.0931464
# [141]	valid_0's binary_logloss: 0.0929699
# [142]	valid_0's binary_logloss: 0.0927973
# [143]	valid_0's binary_logloss: 0.0930815
# [144]	valid_0's binary_logloss: 0.0929235
# [145]	valid_0's binary_logloss: 0.0932795
# [146]	valid_0's binary_logloss: 0.0930412
# [147]	valid_0's binary_logloss: 0.092845
# [148]	valid_0's binary_logloss: 0.0926701
# [149]	valid_0's binary_logloss: 0.0930021
# [150]	valid_0's binary_logloss: 0.0933726
# [151]	valid_0's binary_logloss: 0.0931319
# [152]	valid_0's binary_logloss: 0.0929293
# [153]	valid_0's binary_logloss: 0.0933295
# [154]	valid_0's binary_logloss: 0.0931579
# [155]	valid_0's binary_logloss: 0.0935567
# [156]	valid_0's binary_logloss: 0.093318
# [157]	valid_0's binary_logloss: 0.0932001
# [158]	valid_0's binary_logloss: 0.0929782
# [159]	valid_0's binary_logloss: 0.092778
# [160]	valid_0's binary_logloss: 0.092604
# [161]	valid_0's binary_logloss: 0.0929195
# [162]	valid_0's binary_logloss: 0.0927811
# [163]	valid_0's binary_logloss: 0.0931615
# [164]	valid_0's binary_logloss: 0.0935929
# [165]	valid_0's binary_logloss: 0.0940744
# [166]	valid_0's binary_logloss: 0.0945944
# [167]	valid_0's binary_logloss: 0.0951763
# [168]	valid_0's binary_logloss: 0.0958193
# [169]	valid_0's binary_logloss: 0.0964307
# [170]	valid_0's binary_logloss: 0.0960733
# [171]	valid_0's binary_logloss: 0.0967429
# Early stopping, best iteration is:
# [121]	valid_0's binary_logloss: 0.0921688

# %%
y_pred = model.predict(test.drop(rejected_variables, axis=1))

# %%
sub = pd.DataFrame(test.instance_id, columns=['instance_id'])
sub['predicted_score'] = y_pred
sub.to_csv('sub.txt', sep=' ', index=False)
